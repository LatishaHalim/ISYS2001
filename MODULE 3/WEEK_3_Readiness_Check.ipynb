# %% [markdown]
# <a href="https://colab.research.google.com/github/LatishaHalim/ISYS2001/blob/main/WEEK_3_Readiness_Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ready for WEEK 3!")
# Out:
# Ready for WEEK 3!

# %%
Age = int(input("Your Age: "))
Next_year = Age + 1
# You have to print it in order to work dumbass
# You can't combine int() with a str directly
# You have to convert the int() to a str using [f-sting]
print(f"Next year you will be: {Next_year}")
# Out:
# Your Age: 18
# Next year you will be: 19

# %%
Name = input("What ur name hoe: ")
Hobby = input("What u do when u unemployed: ")

print(f"Yo {Name}, your broke ass is prolly better at being retarded than doing {Hobby}")
# Out:
# What ur name hoe: Latisha
# What u do when u unemployed: Guitar
# Yo Latisha, your broke ass is prolly better at being retarded than doing Guitar

# %%
# Get temp in Celcius from user
# Convert to number (float)
# Apply formula : F = C × 9/5 + 32
# Print the formula with the f-string bruh

C = float(input("Temperature (C): "))
Formula = C * 9/5 + 32
print(f"Temperature in Fahrenheit: {Formula}")
# Out:
# Temperature (C): 32
# Temperature in Fahrenheit: 89.6

# %%
print("=== Smart Grade Calculator ===")

score = float(input("Enter your test score (0-100): "))

if score >= 90:
    print(f"Score: {score} - Grade: A - Excellent!")
elif score >= 80:
    print(f"Score: {score} - Grade: B - Good work!")
elif score >= 70:
    print(f"Score: {score} - Grade: C - Satisfactory")
else:
    print(f"Score: {score} - Grade: F - See instructor")
# Out:
# === Smart Grade Calculator ===
# Enter your test score (0-100): 95.8
# Score: 95.8 - Grade: A - Excellent!

# %%
# IF function

Age = int(input("Input your age: "))

if Age <= 18:
    print(f"Age: {Age} — young")

else:
    print(f"Age: {Age} — Older")
# Out:
# Input your age: 18
# Age: 18 — young
